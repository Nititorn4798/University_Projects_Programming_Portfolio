# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# creating dataframe
df = pd.DataFrame({
    'Age': np.random.randint(10,100,10)
})

# plotting a histogram
plt.hist(df["Age"])
plt.show()
